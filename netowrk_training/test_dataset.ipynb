# %%
from dataset import FallDataset
from torch.utils.data import DataLoader

# %%
dst = FallDataset('./test.csv')

# %%
dataloader = DataLoader(dst, batch_size=32, shuffle=True, num_workers = 8)

# %%
from torchvision import transforms
t = transforms.ToPILImage()
t(dst[0][0])
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F947ED0E2B0>
